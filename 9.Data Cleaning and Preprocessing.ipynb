# %% [markdown]
# ## 1.handling missing data

# %%
import pandas as pd 
import numpy as np

# %%
ps = pd.Series([23,55,np.nan,None])
ps
# Out:
# 0    23.0
# 1    55.0
# 2     NaN
# 3     NaN
# dtype: float64

# %%
ps.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# dtype: bool

# %%
ps.isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# dtype: bool

# %% [markdown]
# ## 2.filtering out missing data

# %%
ps
# Out:
# 0    23.0
# 1    55.0
# 2     NaN
# 3     NaN
# dtype: float64

# %% [markdown]
# ### first methode

# %%
ps.dropna()
# Out:
# 0    23.0
# 1    55.0
# dtype: float64

# %% [markdown]
# ### seconde methode

# %%
ps[ps.notnull()]
# Out:
# 0    23.0
# 1    55.0
# dtype: float64

# %%
# make the change in place

ps.dropna(inplace = True)
ps
# Out:
# 0    23.0
# 1    55.0
# dtype: float64

# %% [markdown]
# ## now working on dataFrames

# %%
# using dropna() on DataFrames means that any row containing nan 
# will be droped 

df = pd.DataFrame([[1,2,None,4], [33,33,34,12] ,[None,23,11,22]])
df
# Out:
#       0   1     2   3
# 0   1.0   2   NaN   4
# 1  33.0  33  34.0  12
# 2   NaN  23  11.0  22

# %%
# we have here two choices deleting the rows or the columns containing nan

# %%
# first the rows 
df.dropna()
# Out:
#       0   1     2   3
# 1  33.0  33  34.0  12

# %%
#or the columns 
df.dropna(axis = 1)
# Out:
#     1   3
# 0   2   4
# 1  33  12
# 2  23  22

# %%
# we can drop only the rows which have nan values on all its columns
df2 = pd.DataFrame([[1,2,None] , [None,None,None], [3,4,None]])
df2
# Out:
#      0    1     2
# 0  1.0  2.0  None
# 1  NaN  NaN  None
# 2  3.0  4.0  None

# %%
df2.dropna(how = 'all')
# Out:
#      0    1     2
# 0  1.0  2.0  None
# 2  3.0  4.0  None

# %%
# or droping a column 
df2.dropna(how = 'all' , axis = 1)
# Out:
#      0    1
# 0  1.0  2.0
# 1  NaN  NaN
# 2  3.0  4.0

# %%
# we can also sepisify the nbr of Nan that we can have

df2
# Out:
#      0    1     2
# 0  1.0  2.0  None
# 1  NaN  NaN  None
# 2  3.0  4.0  None

# %%
df3 = pd.DataFrame([[1,2,3,None] , [1,2,None,None] ,[1,None,None,None]])
df3
# Out:
#    0    1    2     3
# 0  1  2.0  3.0  None
# 1  1  2.0  NaN  None
# 2  1  NaN  NaN  None

# %%
# we keep the rows with less that 2 Nan
#the nbr after thresh is the nbr of valid ovservations( not nan)
df3.dropna(thresh = 2)
# Out:
#    0    1    2     3
# 0  1  2.0  3.0  None
# 1  1  2.0  NaN  None

# %% [markdown]
# ## 3.filling in missing data

# %%
df
# Out:
#       0   1     2   3
# 0   1.0   2   NaN   4
# 1  33.0  33  34.0  12
# 2   NaN  23  11.0  22

# %%
df.fillna(0)
# the missing values were filled by 0
# Out:
#       0   1     2   3
# 0   1.0   2   0.0   4
# 1  33.0  33  34.0  12
# 2   0.0  23  11.0  22

# %%
df.fillna({0:0,2:1})
# Out:
#       0   1     2   3
# 0   1.0   2   1.0   4
# 1  33.0  33  34.0  12
# 2   0.0  23  11.0  22

# %%
df.fillna(method = 'bfill')
# Out:
#       0   1     2   3
# 0   1.0   2  34.0   4
# 1  33.0  33  34.0  12
# 2   NaN  23  11.0  22

# %%
# best practice is using the mean 
df.fillna(df.mean())
# Out:
#       0   1     2   3
# 0   1.0   2  22.5   4
# 1  33.0  33  34.0  12
# 2  17.0  23  11.0  22

# %% [markdown]
# ## 4.remove duplicate entries

# %%
df4 = pd.DataFrame({"name" : ['walid','hamza','bora','walid' ,'bora'] 
                    , "age" : [21,20,21,21,21]})
df4
# Out:
#     name  age
# 0  walid   21
# 1  hamza   20
# 2   bora   21
# 3  walid   21
# 4   bora   21

# %%
# first checking if duplicates exists 
df4.duplicated().any()
# Out:
# True

# %%
# removing duplicates 
df4.drop_duplicates(inplace = True)
df4
# Out:
#     name  age
# 0  walid   21
# 1  hamza   20
# 2   bora   21

# %% [markdown]
# ## 5.replacing values

# %%
df4 = pd.Series([1,2,3,999,-999,5,999])
df4
# Out:
# 0      1
# 1      2
# 2      3
# 3    999
# 4   -999
# 5      5
# 6    999
# dtype: int64

# %%
# replacing abnormal values with nan 
df4.replace([999,-999] ,np.nan, inplace = True)
df4
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    NaN
# 5    5.0
# 6    NaN
# dtype: float64

# %%
df5 = pd.DataFrame(['oui', 'non','oui','oui','oui','non'],
                 columns = ["vaccinated"] )
df5
# Out:
#   vaccinated
# 0        oui
# 1        non
# 2        oui
# 3        oui
# 4        oui
# 5        non

# %%
df5.replace({'oui': 'vaccinated' , 'non' :'not vaccinated'})
# Out:
#        vaccinated
# 0      vaccinated
# 1  not vaccinated
# 2      vaccinated
# 3      vaccinated
# 4      vaccinated
# 5  not vaccinated

# %% [markdown]
# ## 6.renaming columns and index labels

# %%
df6 = pd.DataFrame(np.arange(1,13).reshape(4,3),
                  index = ['black' , 'green' ,'yellow' ,'pink'],
                  columns = ['java', 'pyhton' ,'c++'])
df6
# Out:
#         java  pyhton  c++
# black      1       2    3
# green      4       5    6
# yellow     7       8    9
# pink      10      11   12

# %%
# renaming an index row
df6.rename(index={'pink' : 'red'} ,inplace = True)
df6
# Out:
#         java  pyhton  c++
# black      1       2    3
# green      4       5    6
# yellow     7       8    9
# red       10      11   12

# %%
# renaming columns 
df6.rename(columns = {'c++' : 'c'} , inplace = True)
df6
# Out:
#         java  pyhton   c
# black      1       2   3
# green      4       5   6
# yellow     7       8   9
# red       10      11  12

# %%
df6.index = df6.index.str.title()
df6
# Out:
#         java  pyhton   c
# Black      1       2   3
# Green      4       5   6
# Yellow     7       8   9
# Red       10      11  12

# %%
df6.columns = df6.columns.str.upper()
df6
# Out:
#         JAVA  PYHTON   C
# Black      1       2   3
# Green      4       5   6
# Yellow     7       8   9
# Red       10      11  12

# %% [markdown]
# ## 7.filtering oultliers

# %%
df7 = pd.read_csv("population_by_country_2020.csv")
df7.head()
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1438207241        0.39 %     5540090
# 1                   India         1377233523        0.99 %    13586631
# 2           United States          330610570        0.59 %     1937734
# 3               Indonesia          272931713        1.07 %     2898047
# 4                Pakistan          219992900        2.00 %     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# 1              464          2973190       -532687.0        2.2       28
# 2               36          9147420        954806.0        1.8       38
# 3              151          1811570        -98955.0        2.3       30
# 4              287           770880       -233379.0        3.6       23
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %
# 2        83 %      4.25 %
# 3        56 %      3.51 %
# 4        35 %      2.83 %

# %%
df7.rename(columns= {'Med. Age':'medAge'} , inplace = True)
df7.head()
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1438207241        0.39 %     5540090
# 1                   India         1377233523        0.99 %    13586631
# 2           United States          330610570        0.59 %     1937734
# 3               Indonesia          272931713        1.07 %     2898047
# 4                Pakistan          219992900        2.00 %     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate medAge  \
# 0              153          9388211       -348399.0        1.7     38
# 1              464          2973190       -532687.0        2.2     28
# 2               36          9147420        954806.0        1.8     38
# 3              151          1811570        -98955.0        2.3     30
# 4              287           770880       -233379.0        3.6     23
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %
# 2        83 %      4.25 %
# 3        56 %      3.51 %
# 4        35 %      2.83 %

# %% [markdown]
#  ## 8.shuffling and Random Sampling

# %%
ds8 = pd.Series(np.random.randint(12 , size = 10))
ds8
# Out:
# 0     3
# 1     9
# 2     2
# 3     4
# 4    11
# 5     3
# 6    10
# 7     6
# 8     4
# 9     0
# dtype: int32

# %%
# shuffling  
# frac =1 means keeping 100 % of data 
ds8.sample(frac = 1 )
# Out:
# 2     2
# 1     9
# 7     6
# 6    10
# 8     4
# 5     3
# 4    11
# 9     0
# 3     4
# 0     3
# dtype: int32

# %%
ds8.sample(frac = 1 ).reset_index(drop = True)
# Out:
# 0     9
# 1    10
# 2    11
# 3     2
# 4     0
# 5     4
# 6     4
# 7     6
# 8     3
# 9     3
# dtype: int32

# %%
ds8.sample(frac =.5)
# Out:
# 4    11
# 9     0
# 2     2
# 1     9
# 5     3
# dtype: int32

# %%
df8= pd.read_csv("population_by_country_2020.csv")
df8
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                     China         1438207241        0.39 %     5540090
# 1                     India         1377233523        0.99 %    13586631
# 2             United States          330610570        0.59 %     1937734
# 3                 Indonesia          272931713        1.07 %     2898047
# 4                  Pakistan          219992900        2.00 %     4327022
# ..                      ...                ...           ...         ...
# 230              Montserrat               4991        0.06 %           3
# 231        Falkland Islands               3458        3.05 %         103
# 232                    Niue               1624        0.68 %          11
# 233                 Tokelau               1354        1.27 %          17
# 234                Holy See                801        0.25 %           2
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0                153          9388211       -348399.0        1.7       38
# 1                464          2973190       -532687.0        2.2       28
# 2                 36          9147420        954806.0        1.8       38
# 3                151          1811570        -98955.0        2.3       30
# 4                287           770880       -233379.0        3.6       23
# ..               ...              ...             ...        ...      ...
# 230               50              100             NaN       N.A.     N.A.
# 231                0            12170             NaN       N.A.     N.A.
# 232                6              260             NaN       N.A.     N.A.
# 233              136               10             NaN       N.A.     N.A.
# 234             2003                0             NaN       N.A.     N.A.
#
#     Urban Pop % World Share
# 0          61 %     18.47 %
# 1          35 %     17.70 %
# 2          83 %      4.25 %
# 3          56 %      3.51 %
# 4          35 %      2.83 %
# ..          ...         ...
# 230        10 %      0.00 %
# 231        66 %      0.00 %
# 232        46 %      0.00 %
# 233         0 %      0.00 %
# 234        N.A.      0.00 %
#
# [235 rows x 11 columns]

# %%
df8.sample(frac= .1).reset_index(drop = True)
# Out:
#      Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                     Turkey           84153250        1.09 %      909452
# 1                    Germany           83730223        0.32 %      266897
# 2                 San Marino              33917        0.21 %          71
# 3        Trinidad and Tobago            1398579        0.32 %        4515
# 4                     Guyana             785788        0.48 %        3786
# 5              Côte d'Ivoire           26239250        2.57 %      661730
# 6               Sint Maarten              42776        1.15 %         488
# 7                     Latvia            1890218       -1.08 %      -20545
# 8                      Chile           19082804        0.87 %      164163
# 9                      India         1377233523        0.99 %    13586631
# 10                     Kenya           53521116        2.28 %     1197323
# 11                Guadeloupe             400110        0.02 %          68
# 12                 Australia           25439164        1.18 %      296686
# 13                    Zambia           18273379        2.93 %      522925
# 14                   Iceland             340795        0.65 %        2212
# 15                  Kiribati             119069        1.57 %        1843
# 16                      Togo            8237580        2.43 %      196358
# 17           Solomon Islands             683301        2.55 %       17061
# 18                Cabo Verde             554750        1.10 %        6052
# 19  Czech Republic (Czechia)           10705012        0.18 %       19772
# 20       Antigua and Barbuda              97764        0.84 %         811
# 21                Costa Rica            5084636        0.92 %       46557
# 22                Montserrat               4991        0.06 %           3
# 23                   Andorra              77240        0.16 %         123
#
#     Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0               110           769630        283922.0        2.1       32
# 1               240           348560        543822.0        1.6       46
# 2               566               60             NaN       N.A.     N.A.
# 3               273             5130          -800.0        1.7       36
# 4                 4           196850         -6000.0        2.5       27
# 5                83           318000         -8000.0        4.7       19
# 6              1261               34             NaN       N.A.     N.A.
# 7                30            62200        -14837.0        1.7       44
# 8                26           743532        111708.0        1.7       35
# 9               464          2973190       -532687.0        2.2       28
# 10               94           569140        -10000.0        3.5       20
# 11              237             1690         -1440.0        2.2       44
# 12                3          7682300        158246.0        1.8       38
# 13               25           743390         -8000.0        4.7       18
# 14                3           100250           380.0        1.8       37
# 15              147              810          -800.0        3.6       23
# 16              152            54390         -2000.0        4.4       19
# 17               25            27990         -1600.0        4.4       20
# 18              138             4030         -1342.0        2.3       28
# 19              139            77240         22011.0        1.6       43
# 20              223              440             0.0        2.0       34
# 21              100            51060          4200.0        1.8       33
# 22               50              100             NaN       N.A.     N.A.
# 23              164              470             NaN       N.A.     N.A.
#
#    Urban Pop % World Share
# 0         76 %      1.08 %
# 1         76 %      1.07 %
# 2         97 %      0.00 %
# 3         52 %      0.02 %
# 4         27 %      0.01 %
# 5         51 %      0.34 %
# 6         96 %      0.00 %
# 7         69 %      0.02 %
# 8         85 %      0.25 %
# 9         35 %     17.70 %
# 10        28 %      0.69 %
# 11        N.A.      0.01 %
# 12        86 %      0.33 %
# 13        45 %      0.24 %
# 14        94 %      0.00 %
# 15        57 %      0.00 %
# 16        43 %      0.11 %
# 17        23 %      0.01 %
# 18        68 %      0.01 %
# 19        74 %      0.14 %
# 20        26 %      0.00 %
# 21        80 %      0.07 %
# 22        10 %      0.00 %
# 23        88 %      0.00 %

# %%
df8[df8['Country (or dependency)'] == 'Morocco']
# Out:
#    Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 39                 Morocco           36820713        1.20 %      438791
#
#     Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 39               83           446300        -51419.0        2.4       30
#
#    Urban Pop % World Share
# 39        64 %      0.47 %

# %% [markdown]
# ## 9.Dummy variables

# %%
# dummy variables are used for categorical data (ex : male,female)

df9 = pd.DataFrame({'name': ["walid","hamza","bora"], 
                    'validation':["ratt","ratt","validee"] })
df9
# Out:
#     name validation
# 0  walid       ratt
# 1  hamza       ratt
# 2   bora    validee

# %%
validation_dummies = pd.get_dummies(df9['validation'])
validation_dummies
# Out:
#    ratt  validee
# 0     1        0
# 1     1        0
# 2     0        1

# %%
# now we add it to the original dataframe using the join methode
df9 =df9.join(validation_dummies)

# %%
df9
# Out:
#     name validation  ratt  validee
# 0  walid       ratt     1        0
# 1  hamza       ratt     1        0
# 2   bora    validee     0        1

# %% [markdown]
# ## 10. String object methods

# %%
text1 = "hello, world , my name is walid"
text1.split(',')
# Out:
# ['hello', ' world ', ' my name is walid']

# %%
# getting rid of the spaces 
words = [val.strip() for val in text1.split(',') ]
words
# Out:
# ['hello', 'world', 'my name is walid']
