# %% [markdown]
# ## 1.hierarchical indexing

# %%
import numpy as np 
import pandas as pd

# %%
ps1 = pd.Series(np.random.randn(6) , index=[['2000','2000','2000','2005','2005','2010'] , 
                                            ['one','two','three','one','two','one']])
ps1
# Out:
# 2000  one      0.670359
#       two      0.178112
#       three   -1.018234
# 2005  one      0.720011
#       two      0.381903
# 2010  one     -1.626837
# dtype: float64

# %%
ps1.index
# Out:
# MultiIndex([('2000',   'one'),
#             ('2000',   'two'),
#             ('2000', 'three'),
#             ('2005',   'one'),
#             ('2005',   'two'),
#             ('2010',   'one')],
#            )

# %%
ps1['2000']
# Out:
# one      0.670359
# two      0.178112
# three   -1.018234
# dtype: float64

# %%
ps1['2000': '2005']
# Out:
# 2000  one      0.670359
#       two      0.178112
#       three   -1.018234
# 2005  one      0.720011
#       two      0.381903
# dtype: float64

# %%
ps1[:,'one']
# Out:
# 2000    0.670359
# 2005    0.720011
# 2010   -1.626837
# dtype: float64

# %%
# the methode unstack convert a multi-index serie into dataframe
df1 = ps1.unstack()
df1
# Out:
#            one     three       two
# 2000  0.670359 -1.018234  0.178112
# 2005  0.720011       NaN  0.381903
# 2010 -1.626837       NaN       NaN

# %%
# the methode stack convert a dataframe into a multi-index serie 
df1.stack()
# Out:
# 2000  one      0.670359
#       three   -1.018234
#       two      0.178112
# 2005  one      0.720011
#       two      0.381903
# 2010  one     -1.626837
# dtype: float64

# %%
df1
# Out:
#            one     three       two
# 2000  0.670359 -1.018234  0.178112
# 2005  0.720011       NaN  0.381903
# 2010 -1.626837       NaN       NaN

# %%
df1.fillna(0)
# Out:
#            one     three       two
# 2000  0.670359 -1.018234  0.178112
# 2005  0.720011  0.000000  0.381903
# 2010 -1.626837  0.000000  0.000000

# %%
#set_index()

# %%
# we can do the same for columns

# %% [markdown]
# ## 2.reordering and sorting index levels

# %%
df2 = pd.DataFrame(np.random.randint(50,size=(4,3)), 
                   index=[['black','black','red','red'], ['one','two','one','two']])
df2
# Out:
#             0   1   2
# black one  17  25   1
#       two  26  49  47
# red   one  12  20  33
#       two  19  29  20

# %%
df2v2 = df2.swaplevel(0,1)
df2v2
# Out:
#             0   1   2
# one black  17  25   1
# two black  26  49  47
# one red    12  20  33
# two red    19  29  20

# %%
df2v2.sort_index(level = 0)
# Out:
#             0   1   2
# one black  17  25   1
#     red    12  20  33
# two black  26  49  47
#     red    19  29  20

# %%
# giving a name to the indexex 
df2.index.names = ['color','number']

# %% [markdown]
# ## 3.summary statistics by level

# %%
df2
# Out:
#                0   1   2
# color number
# black one     17  25   1
#       two     26  49  47
# red   one     12  20  33
#       two     19  29  20

# %%
df2.groupby('color').mean()
# Out:
#           0     1     2
# color
# black  21.5  37.0  24.0
# red    15.5  24.5  26.5

# %% [markdown]
# ## 4.indexing with columns in daraframe

# %%
df4 = pd.read_csv('population_by_country_2020.csv')
df4.head()
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1438207241        0.39 %     5540090
# 1                   India         1377233523        0.99 %    13586631
# 2           United States          330610570        0.59 %     1937734
# 3               Indonesia          272931713        1.07 %     2898047
# 4                Pakistan          219992900        2.00 %     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# 1              464          2973190       -532687.0        2.2       28
# 2               36          9147420        954806.0        1.8       38
# 3              151          1811570        -98955.0        2.3       30
# 4              287           770880       -233379.0        3.6       23
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %
# 2        83 %      4.25 %
# 3        56 %      3.51 %
# 4        35 %      2.83 %

# %%
df4.columns
# Out:
# Index(['Country (or dependency)', 'Population (2020)', 'Yearly Change',
#        'Net Change', 'Density (P/Km²)', 'Land Area (Km²)', 'Migrants (net)',
#        'Fert. Rate', 'Med. Age', 'Urban Pop %', 'World Share'],
#       dtype='object')

# %%
df4.set_index('Country (or dependency)', inplace = True)

# %%
df4
# Out:
#                          Population (2020) Yearly Change  Net Change  \
# Country (or dependency)
# China                           1438207241        0.39 %     5540090
# India                           1377233523        0.99 %    13586631
# United States                    330610570        0.59 %     1937734
# Indonesia                        272931713        1.07 %     2898047
# Pakistan                         219992900        2.00 %     4327022
# ...                                    ...           ...         ...
# Montserrat                            4991        0.06 %           3
# Falkland Islands                      3458        3.05 %         103
# Niue                                  1624        0.68 %          11
# Tokelau                               1354        1.27 %          17
# Holy See                               801        0.25 %           2
#
#                          Density (P/Km²)  Land Area (Km²)  Migrants (net)  \
# Country (or dependency)
# China                                153          9388211       -348399.0
# India                                464          2973190       -532687.0
# United States                         36          9147420        954806.0
# Indonesia                            151          1811570        -98955.0
# Pakistan                             287           770880       -233379.0
# ...                                  ...              ...             ...
# Montserrat                            50              100             NaN
# Falkland Islands                       0            12170             NaN
# Niue                                   6              260             NaN
# Tokelau                              136               10             NaN
# Holy See                            2003                0             NaN
#
#                         Fert. Rate Med. Age Urban Pop % World Share
# Country (or dependency)
# China                          1.7       38        61 %     18.47 %
# India                          2.2       28        35 %     17.70 %
# United States                  1.8       38        83 %      4.25 %
# Indonesia                      2.3       30        56 %      3.51 %
# Pakistan                       3.6       23        35 %      2.83 %
# ...                            ...      ...         ...         ...
# Montserrat                    N.A.     N.A.        10 %      0.00 %
# Falkland Islands              N.A.     N.A.        66 %      0.00 %
# Niue                          N.A.     N.A.        46 %      0.00 %
# Tokelau                       N.A.     N.A.         0 %      0.00 %
# Holy See                      N.A.     N.A.        N.A.      0.00 %
#
# [235 rows x 10 columns]

# %%
df4.reset_index( inplace = True)

# %%
df4
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                     China         1438207241        0.39 %     5540090
# 1                     India         1377233523        0.99 %    13586631
# 2             United States          330610570        0.59 %     1937734
# 3                 Indonesia          272931713        1.07 %     2898047
# 4                  Pakistan          219992900        2.00 %     4327022
# ..                      ...                ...           ...         ...
# 230              Montserrat               4991        0.06 %           3
# 231        Falkland Islands               3458        3.05 %         103
# 232                    Niue               1624        0.68 %          11
# 233                 Tokelau               1354        1.27 %          17
# 234                Holy See                801        0.25 %           2
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0                153          9388211       -348399.0        1.7       38
# 1                464          2973190       -532687.0        2.2       28
# 2                 36          9147420        954806.0        1.8       38
# 3                151          1811570        -98955.0        2.3       30
# 4                287           770880       -233379.0        3.6       23
# ..               ...              ...             ...        ...      ...
# 230               50              100             NaN       N.A.     N.A.
# 231                0            12170             NaN       N.A.     N.A.
# 232                6              260             NaN       N.A.     N.A.
# 233              136               10             NaN       N.A.     N.A.
# 234             2003                0             NaN       N.A.     N.A.
#
#     Urban Pop % World Share
# 0          61 %     18.47 %
# 1          35 %     17.70 %
# 2          83 %      4.25 %
# 3          56 %      3.51 %
# 4          35 %      2.83 %
# ..          ...         ...
# 230        10 %      0.00 %
# 231        66 %      0.00 %
# 232        46 %      0.00 %
# 233         0 %      0.00 %
# 234        N.A.      0.00 %
#
# [235 rows x 11 columns]
